# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv("test.csv")
df
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0       0.001497      0.000505         0.036569        0.003224
# 1           1       0.001314      0.000189         0.039106        0.006650
# 2           2       0.001026      0.000234         0.016548        0.009497
# 3           3       0.001435      0.000247         0.011091        0.003639
# 4           4       0.001174      0.000437         0.009011        0.002971
# 5           5       0.001077      0.000281         0.009044        0.003034
# 6           6       0.001155      0.000197         0.009864        0.002667
# 7           7       0.001163      0.000314         0.009810        0.002959
# 8           8       0.001154      0.000207         0.010577        0.003263
# 9           9       0.001196      0.000126         0.025378        0.005748
#
#    param_n_neighbors                            params  split0_test_accuracy  \
# ...

# %%
import pandas as pd

# Encontrar a linha com a maior média de f1
best_f1_row = df.loc[df['mean_test_f1_score'].idxmax()]

# Exibir o resultado
print(best_f1_row)
# Out:
# Unnamed: 0                     9
# mean_fit_time           0.001196
# std_fit_time            0.000126
# mean_score_time         0.025378
# std_score_time          0.005748
#                           ...
# std_train_f1_score      0.007668
# rank_train_recall              1
# rank_train_f1_score            1
# rank_train_accuracy            1
# rank_train_precision           1
# Name: 9, Length: 71, dtype: object
