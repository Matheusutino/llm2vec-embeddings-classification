# %%
# %cd ../..
# Out:
# /home/matheus/Desktop/Itens/Projetos/paper - llm embeddings to classification - marcacini - matheus

# %%
import pandas as pd
from src.core.utils import get_all_files_in_directory

# Obter todos os arquivos no diretório datasets
datasets_path = get_all_files_in_directory("datasets")

# Criar uma lista para armazenar os resultados de cada dataset
results_list = []

# Iterar por cada dataset e calcular as métricas desejadas
for dataset_path in datasets_path:
    df = pd.read_csv(dataset_path)
    
    # Calcular métricas
    num_instances = len(df)
    lengths = df['text'].str.len()
    min_length = lengths.min()
    average_length = lengths.mean()
    max_length = lengths.max()
    variance_length = lengths.std()  # Calcular a variância dos comprimentos de texto
    unique_labels = df['class'].unique()
    num_labels = len(unique_labels)

    # Adicionar as métricas ao results_list
    results_list.append({
        'Dataset': dataset_path,
        'Num Instances': num_instances,
        'Min Length': min_length,
        'Average Length': average_length,
        'Max Length': max_length,
        'Variance Length': variance_length,
        'Unique Labels': unique_labels,
        'Num Labels': num_labels
    })

# Criar um DataFrame a partir da lista de resultados
results = pd.DataFrame(results_list)

# Exibir o DataFrame final
results
# Out:
#                          Dataset  Num Instances  Min Length  Average Length  \
# 0     datasets/SyskillWebert.csv            334        20.0     2330.684685
# 1    datasets/Dmoz-Computers.csv           9500        15.0      132.697158
# 2      datasets/Dmoz-Science.csv           6000        20.0      152.944833
# 3   datasets/Industry Sector.csv           8817         1.0     2496.307474
# 4              datasets/CSTR.csv            299       150.0     1123.638796
# 5          datasets/classic4.csv           7095         4.0      699.549119
# 6   datasets/review_polarity.csv           2000        90.0     3860.642000
# 7               datasets/re8.csv           7674        29.0      585.776909
# 8               datasets/NSF.csv          10524        18.0       74.370391
# 9       datasets/Dmoz-Health.csv           6500        23.0      154.032462
# 10      datasets/Dmoz-Sports.csv          13500        23.0      126.330296
# 11     datasets/webkb-parsed.csv           8282         1.0     2412.206351
#
#     Max Length  Variance Length  \
# 0      55595.0      4283.158572
# 1        692.0        58.706831
# 2        506.0        66.017365
# 3     159727.0      5476.224820
# 4       2807.0       523.477463
# 5       4294.0       552.777570
# 6      14898.0      1700.307541
# 7       5294.0       691.964610
# 8        159.0        28.154993
# 9        489.0        57.580287
# 10       410.0        45.502876
# 11    360353.0      7159.533529
#
#                                         Unique Labels  Num Labels
# 0                   [Bands, BioMedical, Goats, Sheep]           4
# 1   [Artificial, CAD, Companies, Computer, Consult...          18
# 2   [Agriculture, Astronomy, Biology, Chemistry, E...          12
# 3   [basic, capital, conglomerates, consumer, ener...          11
# 4   [ArtificiallIntelligence, Robotics, Systems, T...           4
# 5                             [cacm, cisi, cran, med]           4
# 6                                          [neg, pos]           2
# 7   [acq, crude, earn, grain, interest, money, shi...           8
# 8   [data, ecology, economics, geophysics, graviti...          16
# 9   [Addictions, Alternative, Animal, Conditions, ...          13
# 10  [Baseball, Basketball, Bowling, Cricket, Cycli...          27
# 11  [course, department, faculty, other, project, ...           7
